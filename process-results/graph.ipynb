# %%
import seaborn as sns
import matplotlib.pyplot as plt
from utils import parse_benchmark_to_dataframe
from utils import filter_by_masks
from utils import df_combined_to_markdown
from utils import df_combined_to_csv
from static import *

# %%
df, df_mean, df_sd, df_rsd, df_combined, df_flent = parse_benchmark_to_dataframe(project_dir / "results")

dfs = [
    filter_by_masks(df_combined, masks)
    for masks in filter_masks
]

# %%
gdf = df_flent.groupby(key_cols)

for group, frame in gdf:
    n = len(frame)
    cols = 5 
    rows = 2
    
    # squeeze=False ensures axes is always a 2D array, safely flattenable
    fig, axes = plt.subplots(rows, cols, figsize=(20, 5), squeeze=False)
    axes = axes.flatten()
    
    for i, s in enumerate(frame["tcp_down"]):
        sns.lineplot(data=s, ax=axes[i])
        
    # Remove empty subplots if n isn't a perfect multiple of cols
    for j in range(n, len(axes)):
        fig.delaxes(axes[j])
        
    fig.suptitle(f"Group: {group}")
    plt.tight_layout()
    plt.show()

    # Distribution (Histogram/KDE)
    #sns.histplot(s, kde=True)
    #plt.show()

    # Categorical counts / Bar plot
    #sns.barplot(x=s.index, y=s.values)

# %%
def fetchRow(group):
    return df_combined[
        (df_combined['vpn'] == group[0]) &
        (df_combined['delay'] == group[1]) &
        (df_combined['jitter'] == group[2]) &
        (df_combined['loss'] == group[3]) &
        (df_combined['cpu_freq'] == group[4]) &
        (df_combined['core_count'] == group[5])
    ].iloc[0]

gdf = df_flent.groupby(key_cols)
for group, frame in gdf:
    plt.figure(figsize=(10, 6))
    plt.title(f"Group: {group}")
    for s in frame["down"]:
        row = fetchRow(group)
        ax = sns.lineplot(data=s)
        ax.axhline(y=row["down_mean"], color='red', linestyle='-', linewidth=0.5)
    plt.show()
